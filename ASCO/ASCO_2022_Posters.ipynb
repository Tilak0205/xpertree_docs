# %%
import os
import sys
import traceback
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver import ActionChains
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
driver=webdriver.Chrome()
driver.get("https://meetings.asco.org/meetings/2022-asco-annual-meeting/288/program-guide/posters")
driver.maximize_window()

# %%
session=[]
Presentation=[]
Presenter=[]
PAffil=[]

# %%
li=driver.find_elements(By.CLASS_NAME,"session-card")
li1=[]
li2=[]
li3=[]
for i in li:
    if("Play Session" in i.text):
        li1.append(i.find_element(By.TAG_NAME,"a"))
        li3.append(i.find_element(By.CLASS_NAME,"pseudo-hover").text)
for i in li1:
    li2.append(i.get_attribute('href'))
li4=li2
a=ActionChains(driver)

# %%
driver.get()

# %%
print(len(li2))
i=0
while(i!=len(li2)):
    try:
        driver.get(li2[i])
    except:    
        driver.get(li4[i])
    driver.implicitly_wait(10)
    ss=li3[i]
    print(ss)
    li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
    if(li1==[]):
        driver.implicitly_wait(10)
        li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
    j=0
    while(j!=len(li1)):
        li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
        print(i,j)
        try:
            li1[j].click()
        except:
            driver.refresh()
            li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
            li1[j].click()
        pp=driver.find_element(By.CLASS_NAME,"h4").text
        m=driver.find_elements(By.CLASS_NAME,"m-0")
        s=0
        while(s<len(m)):
            session.append(ss)
            Presentation.append(pp)
            try:
                Presenter.append(m[s].text)
            except:
                Presenter.append(None)
            try:
                PAffil.append(m[s+1].text)
            except:
                PAffil.append(None)
            s+=2
        j+=1
    i+=1

# %%
session=[]
sub_sess=[]
Author=[]
Organisation=[]
Sub_track=[]
backgrund=[]
methods=[]
results=[]
Concl=[]

# %%
li=driver.find_elements(By.CLASS_NAME,"session-card")
li1=[]
li2=[]
li3=[]
for i in li:
    if("Play Session" not in i.text):
        li1.append(i.find_element(By.TAG_NAME,"a"))
        li3.append(i.find_element(By.CLASS_NAME,"pseudo-hover").text)
for i in li1:
    li2.append(i.get_attribute('href'))

li4=li2
a=ActionChains(driver)

# %%
print(len(li2))
i=22
while(i!=len(li2)):
    try:
        driver.get(li2[i])
    except:    
        driver.get(li4[i])
    driver.implicitly_wait(20)
    ss=li3[i]
    print(ss)
    agenda_item=driver.find_elements(By.CLASS_NAME,"agenda__item")
    if(agenda_item==[]):
        driver.implicitly_wait(20)
        agenda_item=driver.find_elements(By.CLASS_NAME,"agenda__item")
    ABST=[]
    AB=driver.find_elements(By.CLASS_NAME,"social-label")
    
    for m in AB:
        if("Abstract" in m.text):
            ABST.append(m)
    li1=driver.find_elements(By.CLASS_NAME,"eyebrow")
    if(i==22):
        j=45
    else:
        j=0
#     j=0
    r=j
    while(j!=len(li1)):
        li1=driver.find_elements(By.CLASS_NAME,"eyebrow")
        print(i,j)
        try:
            li1[j].click()
        except:
            driver.refresh()
            driver.implicitly_wait(15)
            li1=driver.find_elements(By.CLASS_NAME,"eyebrow")
            li1[j].click()
#         ABST=driver.find_elements(By.CLASS_NAME,"social-label")
        if("Abstract" not in agenda_item[j].text):
            j+=1
            continue
        else:
#             session.append(ss)
            s_ss=agenda_item[j].find_element(By.TAG_NAME,"p").text
            try:
                x=driver.find_element(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div/div/asco-collapsible-panel/mat-drawer-container/mat-drawer/div/div/mat-tab-group/div/mat-tab-body[1]/div/asco-agenda/div/div["+str(j+2)+"]/div/asco-session-presentation-details/div/asco-simple-drawer/div[1]")
                x.click()
            except:
                driver.refresh()
                li1=driver.find_elements(By.CLASS_NAME,"eyebrow")
                li1[j].click()
                x=driver.find_element(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div/div/asco-collapsible-panel/mat-drawer-container/mat-drawer/div/div/mat-tab-group/div/mat-tab-body[1]/div/asco-agenda/div/div["+str(j+2)+"]/div/asco-session-presentation-details/div/asco-simple-drawer/div[1]")
                x.click()
            xs=driver.find_elements(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div/div/asco-collapsible-panel/mat-drawer-container/mat-drawer/div/div/mat-tab-group/div/mat-tab-body[1]/div/asco-agenda/div/div["+str(j+2)+"]/div/asco-session-presentation-details/div/asco-simple-drawer/div[2]/div/div[2]/p")
            if(xs==[]):
                s_t=None
            else:
                s_t=xs[0].text
            sp=driver.find_elements(By.CLASS_NAME,"item-header")
            auth=driver.find_elements(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div/div/asco-collapsible-panel/mat-drawer-container/mat-drawer/div/div/mat-tab-group/div/mat-tab-body[1]/div/asco-agenda/div/div["+str(j+2)+"]/div/asco-session-presentation-details/div/asco-simple-drawer/div[2]/div/div[3]/p")
            if(auth==[]):
                auth1=[None]
#                 Author.append(None)
            else:
                auth1=auth[0].text.split(",")
#                 Author.append(auth[0].text)
            orgs=driver.find_elements(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div/div/asco-collapsible-panel/mat-drawer-container/mat-drawer/div/div/mat-tab-group/div/mat-tab-body[1]/div/asco-agenda/div/div["+str(j+2)+"]/div/asco-session-presentation-details/div/asco-simple-drawer/div[2]/div/div[4]/p")
            if(orgs==[]):
                orgs1=None
            else:
                orgs1=orgs[0].text
            ABST[r].click()
            r+=1
            for k in range(len(auth1)):    
                session.append(ss)
                Sub_track.append(s_t)
                sub_sess.append(s_ss)
                Author.append(auth1[k].strip())
                Organisation.append(orgs1)
                para=driver.find_elements(By.XPATH,"/html/body/div[3]/div[2]/div/mat-dialog-container/asco-modal/div/div/asco-abstract/div/div/asco-safe-html/div/p")
                lis2=para[0].text.split("\n")
                if("Background:" in lis2):
                    backgrund.append(lis2[lis2.index("Background:")+1])
                else:
                    backgrund.append(None)
                if("Methods:" in lis2):
                    methods.append(lis2[lis2.index("Methods:")+1])
                else:
                    methods.append(None)
                if("Results:" in lis2):
                    results.append(lis2[lis2.index("Results:")+1])
                else:
                    results.append(None)
                if("Conclusions:" in lis2):
                    Concl.append(lis2[lis2.index("Conclusions:")+1])
                else:
                    Concl.append(None)
            button=driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div/mat-dialog-container/asco-modal/div/h3/button").click()
            j+=1
#             li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
#     driver.back()
    driver.implicitly_wait(5)
#     li=driver.find_elements(By.CLASS_NAME,"pseudo-hover")
    i+=1
# Out:
# 24
# Genitourinary Cancer—Prostate, Testicular, and Penile
# 22 45
# 22 46
# 22 47
# 22 48
# 22 49
# 22 50
# 22 51
# 22 52
# 22 53
# 22 54
# 22 55
# 22 56
# 22 57
# 22 58
# 22 59
# 22 60
# 22 61
# 22 62
# 22 63
# 22 64
# 22 65
# 22 66
# 22 67
# 22 68
# 22 69
# 22 70
# 22 71
# 22 72
# 22 73
# 22 74
# 22 75
# 22 76
# 22 77
# 22 78
# 22 79
# 22 80
# 22 81
# 22 82
# 22 83
# 22 84
# 22 85
# 22 86
# 22 87
# 22 88
# 22 89
# 22 90
# 22 91
# 22 92
# 22 93
# Health Services Research and Quality Improvement
# 23 0
# 23 1
# 23 2
# 23 3
# 23 4
# 23 5
# 23 6
# 23 7
# 23 8
# 23 9
# 23 10
# 23 11
# 23 12
# 23 13
# 23 14
# 23 15
# 23 16
# 23 17
# 23 18
# 23 19
# 23 20
# 23 21
# 23 22
# 23 23
# 23 24
# 23 25
# 23 26
# 23 27
# 23 28
# 23 29
# 23 30
# 23 31
# 23 32
# 23 33
# 23 34
# 23 35
# 23 36
# 23 37
# 23 38
# 23 39
# 23 40
# 23 41
# 23 42
# 23 43
# 23 44
# 23 45
# 23 46
# 23 47
# 23 48
# 23 49
# 23 50
# 23 51
# 23 52
# 23 53
# 23 54
# 23 55
# 23 56
# 23 57
# 23 58
# 23 59
# 23 60
# 23 61
# 23 62
# ...

# %%
li3[13]
# Out:
# 'Developmental Therapeutics—Immunotherapy'

# %%
session=[]
sub_sess=[]
Author=[]
Organisation=[]
Sub_track=[]
backgrund=[]
methods=[]
results=[]
Concl=[]

# %%
li=driver.find_elements(By.CLASS_NAME,"session-card")
li1=[]
li2=[]
li3=[]
for i in li:
    if("Play Session" in i.text):
        li1.append(i.find_element(By.TAG_NAME,"a"))
        li3.append(i.find_element(By.CLASS_NAME,"pseudo-hover").text)
for i in li1:
    li2.append(i.get_attribute('href'))
li4=li2
a=ActionChains(driver)

# %%
print(len(li2))
i=0
while(i!=len(li2)):
    try:
        
        driver.get(li2[i])
    except:    
        driver.get(li4[i])
    driver.implicitly_wait(10)
    ss=li3[i]
    print(ss)
    
    
    li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
    j=0
    for s in range(0,10 if len(li1)>10 else len(li1)):
        li1[s].click()
    while(j!=len(li1)):
        li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
        print(i,j)
        if(j==9):
            driver.refresh()
            driver.implicitly_wait(7)
            li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
            for s in range(9,len(li1)):
                li1[s].click()  
        try:
            li1[j].click()
        except:
            driver.refresh()
            li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
#             a.move_to_element(li1[j]).perform()
            li1[j].click()
        ab=driver.find_element(By.CLASS_NAME,"detail-buttons").text
        if('Abstract' not in ab):
            j+=1
            continue
        
        else:
#             session.append(ss)
            AB=driver.find_elements(By.CLASS_NAME,"social-label")
            for l in AB:
                if('Abstract' in l.text):
                    ABST=l
            s_ss=driver.find_element(By.CLASS_NAME,"h4").text
            x=driver.find_elements(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div[2]/div/div/div[2]/asco-session-presentation-details/div/asco-simple-drawer/div[2]/div/div[2]/p")
            if(x==[]):
                s_t=None
            else:
                s_t=x[0].text
            sp=driver.find_elements(By.CLASS_NAME,"item-header")
            auth=driver.find_elements(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div[2]/div/div/div[2]/asco-session-presentation-details/div/asco-simple-drawer/div[2]/div/div[3]/p")
            if(auth==[]):
                auth1=[None]
#                 Author.append(None)
            else:
                auth1=auth[0].text.split(",")
#                 Author.append(auth[0].text)
            orgs=driver.find_elements(By.XPATH,"/html/body/asco-root/div/asco-session-page/asco-session/div/div[2]/div/div/div[2]/asco-session-presentation-details/div/asco-simple-drawer/div[2]/div/div[4]/p")
            if(orgs==[]):
                orgs1=None
            else:
                orgs1=orgs[0].text
            ABST.click()
            for k in range(len(auth1)):    
                session.append(ss)
                Sub_track.append(s_t)
                sub_sess.append(s_ss)
                Author.append(auth1[k].strip())
                Organisation.append(orgs1)
                para=driver.find_elements(By.XPATH,"/html/body/div[3]/div[2]/div/mat-dialog-container/asco-modal/div/div/asco-abstract/div/div/asco-safe-html/div/p")
                lis2=para[0].text.split("\n")
                if("Background:" in lis2):
                    backgrund.append(lis2[lis2.index("Background:")+1])
                else:
                    backgrund.append(None)
                if("Methods:" in lis2):
                    methods.append(lis2[lis2.index("Methods:")+1])
                else:
                    methods.append(None)
                if("Results:" in lis2):
                    results.append(lis2[lis2.index("Results:")+1])
                else:
                    results.append(None)
                if("Conclusions:" in lis2):
                    Concl.append(lis2[lis2.index("Conclusions:")+1])
                else:
                    Concl.append(None)
            button=driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div/mat-dialog-container/asco-modal/div/h3/button").click()
            j+=1
#             li1=driver.find_elements(By.CLASS_NAME,"mat-list-item-content")
#     driver.back()
    driver.implicitly_wait(5)
#     li=driver.find_elements(By.CLASS_NAME,"pseudo-hover")
    i+=1

# %%
import pandas as pd

# %%
Data2=pd.DataFrame()

# %%
conference=[]
for i in range(len(session)):
    conference.append("American Society of Clinical Oncology ASCO - 2022")

# %%
Data2['SESSION_NAMES']=session
Data2["SUB_SESSIONS"]=sub_sess
Data2["Author"]=Author
Data2["Organization"]=Organisation
Data2["Sub_track"]=Sub_track
Data2["backgrund"]=backgrund
Data2["methods"]=methods
Data2["results"]=results
Data2["Concl"]=Concl

# %%
Data2.to_excel("ASCO_POSTERS_2022_1.xlsx")
